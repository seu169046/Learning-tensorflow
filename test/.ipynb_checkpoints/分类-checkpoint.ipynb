# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# D:\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
(train_image, train_label), (test_image, test_label)=tf.keras.datasets.fashion_mnist.load_data()

# %%
plt.imshow(train_image[0])

# %%
train_image.shape, test_image.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
train_label[0], test_label[0]
# Out:
# (9, 9)

# %%
plt.imshow(test_image[0])

# %%
np.max(train_image), np.max(test_image)
# Out:
# (255, 255)

# %%
train_iamge = train_image/255
train_image1 = train_image[:50000,:]
test_image = train_image[50000:,:]

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_5 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['acc'])
model.fit(train_image, train_label, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 4.2875 - acc: 0.7190
# Epoch 2/10
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.6512 - acc: 0.7490
# Epoch 3/10
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.5470 - acc: 0.8042
# Epoch 4/10
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.5308 - acc: 0.8169
# Epoch 5/10
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.4919 - acc: 0.8305
# Epoch 6/10
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.4761 - acc: 0.8375
# Epoch 7/10
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.4654 - acc: 0.8427
# Epoch 8/10
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.4521 - acc: 0.8456
# Epoch 9/10
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.4529 - acc: 0.8454
# Epoch 10/10
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.4436 - acc: 0.8502

# %%
model.evaluate(test_image, test_label)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [2.654090335845947, 0.1]

# %%
train_label_onehot = tf.keras.utils.to_categorical(train_label)
train_label_onehot1 = train_label_onehot[:50000,:]
test_label_onehot = train_label_onehot[50000:,:]

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
             loss='categorical_crossentropy',
             metrics=['acc'])
model.fit(train_image, train_label_onehot, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 188s 3ms/sample - loss: 3.9364 - acc: 0.6847
# Epoch 2/5
# 60000/60000 [==============================] - 188s 3ms/sample - loss: 0.6923 - acc: 0.7418
# Epoch 3/5
# 60000/60000 [==============================] - 188s 3ms/sample - loss: 0.6607 - acc: 0.7640
# Epoch 4/5
# 60000/60000 [==============================] - 188s 3ms/sample - loss: 0.5562 - acc: 0.8066
# Epoch 5/5
# 60000/60000 [==============================] - 190s 3ms/sample - loss: 0.5249 - acc: 0.8179

# %%
predict = model.predict(test_image)

# %%
predict.shape
# Out:
# (10000, 10)

# %%
np.argmax(predict, axis=1)
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int64)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.6))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.6))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.6))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_5 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 134,794
# Trainable params: 134,794
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
             loss='categorical_crossentropy',
             metrics=['acc'])
history = model.fit(train_image1, train_label_onehot1, epochs=10, validation_data=(test_image,test_label_onehot))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 39s 780us/sample - loss: 1.6563 - acc: 0.7427 - val_loss: 0.8285 - val_acc: 0.7590
# Epoch 2/10
# 50000/50000 [==============================] - 36s 723us/sample - loss: 0.5729 - acc: 0.8069 - val_loss: 0.5214 - val_acc: 0.8094
# Epoch 3/10
# 50000/50000 [==============================] - 37s 743us/sample - loss: 0.4874 - acc: 0.8306 - val_loss: 0.5084 - val_acc: 0.8147
# Epoch 4/10
# 50000/50000 [==============================] - 38s 768us/sample - loss: 0.4447 - acc: 0.8427 - val_loss: 0.4536 - val_acc: 0.8379
# Epoch 5/10
# 50000/50000 [==============================] - 40s 792us/sample - loss: 0.4201 - acc: 0.8488 - val_loss: 0.4354 - val_acc: 0.8497
# Epoch 6/10
# 50000/50000 [==============================] - 38s 761us/sample - loss: 0.3956 - acc: 0.8579 - val_loss: 0.4184 - val_acc: 0.8529
# Epoch 7/10
# 50000/50000 [==============================] - 35s 700us/sample - loss: 0.3832 - acc: 0.8608 - val_loss: 0.4191 - val_acc: 0.8521
# Epoch 8/10
# 50000/50000 [==============================] - 38s 766us/sample - loss: 0.3716 - acc: 0.8671 - val_loss: 0.4216 - val_acc: 0.8542
# Epoch 9/10
# 50000/50000 [==============================] - 37s 738us/sample - loss: 0.3631 - acc: 0.8696 - val_loss: 0.3952 - val_acc: 0.8658
# Epoch 10/10
# 50000/50000 [==============================] - 35s 701us/sample - loss: 0.3524 - acc: 0.8730 - val_loss: 0.3937 - val_acc: 0.8663

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
plt.plot(history.epoch, history.history.get('loss'), label='train_loss')
plt.plot(history.epoch, history.history.get('val_loss'), label='val_loss')
plt.legend()
