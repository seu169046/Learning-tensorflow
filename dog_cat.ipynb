# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import glob
import os

# %%
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# Tensorflow version: 2.2.0

# %%
train_image_path=glob.glob('./data/dc/training_set/*/*.jpg')
test_image_path=glob.glob('./data/dc/test_set/*/*.jpg')
print(len(train_image_path))
print(len(test_image_path))
# Out:
# 8005
# 2023

# %%
train_image_label=[int(os.path.basename(p).split('.')[0]=='cat') for p in train_image_path]
test_image_label=[int(os.path.basename(p).split('.')[0]=='cat') for p in test_image_path]

# %%
test_image_label[-5:]
# Out:
# [0, 0, 0, 0, 0]

# %%
def load_preprocess_image(path,label):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image,channels=3)
    image = tf.image.resize(image,[320,320])
    image = tf.image.random_crop(image,[256,256,3])
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
#     image = tf.image.random_brightness(image,0.5)
#     image = tf.image.random_contrast(image,0,1)
    image = tf.cast(image, tf.float32)
    image = image/255
    label = tf.reshape(label,[1])
    return image,label

# %%
def load_preprocess_image_test(path,label):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image,channels=3)
    image = tf.image.resize(image,[256,256])
    image = tf.cast(image, tf.float32)
    image = image/255
    label = tf.reshape(label,[1])
    return image,label

# %%
train_image_ds=tf.data.Dataset.from_tensor_slices((train_image_path, train_image_label))
test_image_ds=tf.data.Dataset.from_tensor_slices((test_image_path, test_image_label))

# %%
AUTOTUNE=tf.data.experimental.AUTOTUNE
train_image_ds=train_image_ds.map(load_preprocess_image,num_parallel_calls=AUTOTUNE)
test_image_ds=test_image_ds.map(load_preprocess_image_test,num_parallel_calls=AUTOTUNE)

# %%
test_image_ds
# Out:
# <PrefetchDataset shapes: ((None, 256, 256, 3), (None, 1)), types: (tf.float32, tf.int32)>

# %%
for img, label in train_image_ds.take(1):
    plt.imshow(img)

# %%
BATCH_SIZE=128
train_count = len(train_image_path)
train_image_ds=train_image_ds.shuffle(train_count).batch(BATCH_SIZE)
train_image_ds=train_image_ds.prefetch(AUTOTUNE).repeat()

test_image_ds=test_image_ds.batch(BATCH_SIZE)
test_image_ds=test_image_ds.prefetch(AUTOTUNE).repeat()

# %%
# imgs, lables = next(iter(train_image_ds))
# imgs.shape

# %%
# plt.imshow(imgs[0])

# %%
# lables[0]

# %%
model = keras.Sequential([
    tf.keras.layers.Conv2D(64,(3,3),input_shape=(256,256,3),padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
#     tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
    tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
#     tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
    tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
#     tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(256,(1,1),activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(),
#     tf.keras.layers.Conv2D(512,(3,3),activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Conv2D(512,(3,3),activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Conv2D(512,(1,1),activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(512,(3,3),activation='relu'),
    tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Conv2D(512,(3,3),activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Conv2D(512,(1,1),activation='relu'),
#     tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1024,activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(256,activation='relu'),
#     tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(1)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 64)      1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 64)      256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 126, 126, 128)     73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 126, 126, 128)     512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 63, 63, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 61, 61, 256)       295168
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 61, 61, 256)       1024
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 61, 61, 256)       65792
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 61, 61, 256)       1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 28, 512)       2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,413,697
# Trainable params: 2,409,217
# Non-trainable params: 4,480
# _________________________________________________________________

# %%
# pred = model(imgs)
# pred.shape

#
# np.array([p[0].numpy() for p in tf.cast(pred>0, tf.int32)])
#
#
#
# np.array([l[0].numpy() for l in lables])
#
#
# ls = tf.keras.losses.BinaryCrossentropy()
# ls([[0.],[0.],[1.],[1.]],[[1.],[1.],[1.],[1.]])
#
#
#
# tf.keras.losses.binary_crossentropy([0.,0.,1.,1.],[1.,1.,1.,1.])

# %%
optimizer=tf.keras.optimizers.Adam()

# %%
epoch_loss_avg=tf.keras.metrics.Mean('train_loss')
train_accuracy=tf.keras.metrics.Accuracy()

test_loss_avg=tf.keras.metrics.Mean('test_loss')
test_accuracy=tf.keras.metrics.Accuracy()

# %%
def train_step(model,images,labels):
    with tf.GradientTape() as t:
        pred = model(images)
        loss_step = tf.keras.losses.BinaryCrossentropy(from_logits=True)(labels,pred)
    grads = t.gradient(loss_step,model.trainable_variables)
    optimizer.apply_gradients(zip(grads,model.trainable_variables))
    epoch_loss_avg(loss_step)
    train_accuracy(labels,tf.cast(pred>0,tf.int32))

# %%
def test_step(model,images,labels):
    pred_test = model.predict(images)
    loss_step_test = tf.keras.losses.BinaryCrossentropy(from_logits=True)(labels,pred_test)
    test_loss_avg(loss_step_test)
    test_accuracy(labels,tf.cast(pred_test>0,tf.int32))

# %%
num_epoch=50

import datetime
current_time=datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir='logs/dog_cat'+current_time+'/train'
test_log_dir='logs/dog_cat'+current_time+'/test'

train_writer=tf.summary.create_file_writer(train_log_dir)
test_writer=tf.summary.create_file_writer(test_log_dir)

# %%
for epoch in range(num_epoch):
    for imgs_,lables_ in train_image_ds:
        train_step(model,imgs_,lables_)
        print('.',end='')
    print()
    with train_writer.as_default():
        tf.summary.scalar('train_loss',epoch_loss_avg.result(),step=epoch)
        tf.summary.scalar('train_acc',train_accuracy.result(),step=epoch)


    for imgs_,lables_ in test_image_ds:
        test_step(model,imgs_,lables_)
        print('.',end='')
    print()
    with test_writer.as_default():
        tf.summary.scalar('test_loss',test_loss_avg.result(),step=epoch)
        tf.summary.scalar('test_acc',test_accuracy.result(),step=epoch)

    print("Epoch:{}; loss:{:.3f}; accuracy:{:.3f}; test_loss{:.3f},accuracy_test:{:.3f}".format(
        epoch+1,
        epoch_loss_avg.result(),
        train_accuracy.result(),
        test_loss_avg.result(),
        test_accuracy.result()
    ))
    epoch_loss_avg.reset_states()
    train_accuracy.reset_states()
    test_loss_avg.reset_states()
    test_accuracy.reset_states()

# %%
def train_step(model,images,labels):
    with tf.GradientTape() as t:
        pred = model(images)
        loss_step = tf.keras.losses.BinaryCrossentropy(from_logits=True)(labels,pred)
    grads = t.gradient(loss_step,model.trainable_variables)
    optimizer.apply_gradients(zip(grads,model.trainable_variables))
    epoch_loss_avg(loss_step)
    train_accuracy(labels,tf.cast(pred>0,tf.int32))

# %%
def test_step(model,images,labels):
    pred_test = model.predict(images)
    loss_step_test = tf.keras.losses.BinaryCrossentropy(from_logits=True)(labels,pred_test)
    test_loss_avg(loss_step_test)
    test_accuracy(labels,tf.cast(pred_test>0,tf.int32))

# %%
num_epoch=50

import datetime
current_time=datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir='logs/dog_cat'+current_time+'/train'
test_log_dir='logs/dog_cat'+current_time+'/test'

train_writer=tf.summary.create_file_writer(train_log_dir)
test_writer=tf.summary.create_file_writer(test_log_dir)

# %%
for epoch in range(num_epoch):
    for imgs_,lables_ in train_image_ds:
        train_step(model,imgs_,lables_)
        print('.',end='')
    print()
    with train_writer.as_default():
        tf.summary.scalar('train_loss',epoch_loss_avg.result(),step=epoch)
        tf.summary.scalar('train_acc',train_accuracy.result(),step=epoch)


    for imgs_,lables_ in test_image_ds:
        test_step(model,imgs_,lables_)
        print('.',end='')
    print()
    with test_writer.as_default():
        tf.summary.scalar('test_loss',test_loss_avg.result(),step=epoch)
        tf.summary.scalar('test_acc',test_accuracy.result(),step=epoch)

    print("Epoch:{}; loss:{:.3f}; accuracy:{:.3f}; test_loss{:.3f},accuracy_test:{:.3f}".format(
        epoch+1,
        epoch_loss_avg.result(),
        train_accuracy.result(),
        test_loss_avg.result(),
        test_accuracy.result()
    ))
    epoch_loss_avg.reset_states()
    train_accuracy.reset_states()
    test_loss_avg.reset_states()
    test_accuracy.reset_states()
# Out:
# ...............................................................
# ................
# Epoch:1; loss:0.697; accuracy:0.513; test_loss0.693,accuracy_test:0.500
# ...............................................................
# ................
# Epoch:2; loss:0.679; accuracy:0.550; test_loss0.673,accuracy_test:0.596
# ...............................................................
# ................
# Epoch:3; loss:0.661; accuracy:0.600; test_loss0.661,accuracy_test:0.608
# ...............................................................
# ................
# Epoch:4; loss:0.660; accuracy:0.604; test_loss0.649,accuracy_test:0.623
# ...............................................................
# ................
# Epoch:5; loss:0.627; accuracy:0.645; test_loss0.616,accuracy_test:0.662
# ...............................................................
# ................
# Epoch:6; loss:0.605; accuracy:0.674; test_loss0.638,accuracy_test:0.636
# ...............................................................
# ................
# Epoch:7; loss:0.587; accuracy:0.691; test_loss0.571,accuracy_test:0.701
# ...............................................................
# ................
# Epoch:8; loss:0.570; accuracy:0.704; test_loss0.613,accuracy_test:0.658
# ...............................................................
# ................
# Epoch:9; loss:0.553; accuracy:0.721; test_loss0.589,accuracy_test:0.688
# ...............................................................
# ................
# Epoch:10; loss:0.537; accuracy:0.735; test_loss0.585,accuracy_test:0.696
# ...............................................................
# ................
# Epoch:11; loss:0.526; accuracy:0.743; test_loss0.556,accuracy_test:0.718
# ...............................................................
# ................
# Epoch:12; loss:0.516; accuracy:0.749; test_loss0.630,accuracy_test:0.677
# ...............................................................
# ................
# Epoch:13; loss:0.511; accuracy:0.754; test_loss0.529,accuracy_test:0.755
# ...............................................................
# ................
# Epoch:14; loss:0.490; accuracy:0.766; test_loss0.482,accuracy_test:0.766
# ...............................................................
# ................
# Epoch:15; loss:0.492; accuracy:0.765; test_loss0.523,accuracy_test:0.736
# ...............................................................
# ................
# Epoch:16; loss:0.483; accuracy:0.775; test_loss0.539,accuracy_test:0.723
# ...............................................................
# ................
# Epoch:17; loss:0.473; accuracy:0.778; test_loss0.483,accuracy_test:0.774
# ...............................................................
# ................
# Epoch:18; loss:0.446; accuracy:0.797; test_loss0.521,accuracy_test:0.739
# ...............................................................
# ................
# Epoch:19; loss:0.418; accuracy:0.814; test_loss0.483,accuracy_test:0.767
# ...............................................................
# ................
# Epoch:20; loss:0.403; accuracy:0.821; test_loss0.522,accuracy_test:0.761
# ...............................................................
# ................
# Epoch:21; loss:0.408; accuracy:0.814; test_loss0.451,accuracy_test:0.781
# ...............................................................
# ................
# Epoch:22; loss:0.389; accuracy:0.826; test_loss0.448,accuracy_test:0.799
# ...............................................................
# ................
# Epoch:23; loss:0.399; accuracy:0.821; test_loss0.499,accuracy_test:0.761
# ...............................................................
# ................
# Epoch:24; loss:0.357; accuracy:0.844; test_loss0.393,accuracy_test:0.820
# ...............................................................
# ................
# Epoch:25; loss:0.345; accuracy:0.844; test_loss0.442,accuracy_test:0.813
# ...............................................................
# ................
# Epoch:26; loss:0.324; accuracy:0.857; test_loss0.373,accuracy_test:0.843
# ...............................................................
# ................
# Epoch:27; loss:0.320; accuracy:0.861; test_loss0.367,accuracy_test:0.837
# ...............................................................
# ................
# Epoch:28; loss:0.302; accuracy:0.868; test_loss0.353,accuracy_test:0.843
# ...............................................................
# ................
# Epoch:29; loss:0.287; accuracy:0.879; test_loss0.320,accuracy_test:0.857
# ...............................................................
# ................
# Epoch:30; loss:0.280; accuracy:0.880; test_loss0.427,accuracy_test:0.816
# ...............................................................
# ................
# Epoch:31; loss:0.265; accuracy:0.888; test_loss0.361,accuracy_test:0.842
# ...............................................................
# ................
# Epoch:32; loss:0.249; accuracy:0.896; test_loss0.412,accuracy_test:0.826
# ...............................................................
# ................
# Epoch:33; loss:0.241; accuracy:0.900; test_loss0.347,accuracy_test:0.860
# ...............................................................
# ................
# Epoch:34; loss:0.230; accuracy:0.902; test_loss0.295,accuracy_test:0.879
# ...............................................................
# ................
# Epoch:35; loss:0.210; accuracy:0.910; test_loss0.308,accuracy_test:0.869
# ...............................................................
# ................
# Epoch:36; loss:0.220; accuracy:0.908; test_loss0.331,accuracy_test:0.871
# ...............................................................
# ................
# Epoch:37; loss:0.201; accuracy:0.917; test_loss0.292,accuracy_test:0.878
# ...............................................................
# ................
# Epoch:38; loss:0.192; accuracy:0.921; test_loss0.312,accuracy_test:0.874
# ...............................................................
# ................
# Epoch:39; loss:0.193; accuracy:0.918; test_loss0.410,accuracy_test:0.848
# ...............................................................
# ................
# Epoch:40; loss:0.208; accuracy:0.911; test_loss0.262,accuracy_test:0.896
# ...............................................................
# ................
# Epoch:41; loss:0.195; accuracy:0.924; test_loss0.256,accuracy_test:0.898
# ...............................................................
# ................
# Epoch:42; loss:0.177; accuracy:0.929; test_loss0.310,accuracy_test:0.873
# ...............................................................
# ................
# Epoch:43; loss:0.183; accuracy:0.927; test_loss0.262,accuracy_test:0.891
# ...............................................................
# ................
# Epoch:44; loss:0.154; accuracy:0.937; test_loss0.262,accuracy_test:0.885
# ...............................................................
# ................
# Epoch:45; loss:0.159; accuracy:0.934; test_loss0.272,accuracy_test:0.896
# ...............................................................
# ................
# Epoch:46; loss:0.150; accuracy:0.939; test_loss0.283,accuracy_test:0.903
# ...............................................................
# ................
# Epoch:47; loss:0.152; accuracy:0.938; test_loss0.283,accuracy_test:0.886
# ...............................................................
# ................
# Epoch:48; loss:0.147; accuracy:0.940; test_loss0.250,accuracy_test:0.892
# ...............................................................
# ................
# Epoch:49; loss:0.126; accuracy:0.949; test_loss0.286,accuracy_test:0.891
# ...............................................................
# ................
# Epoch:50; loss:0.134; accuracy:0.947; test_loss0.248,accuracy_test:0.900
